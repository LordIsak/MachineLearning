# %% [markdown]
# <a href="https://colab.research.google.com/github/LordIsak/MachineLearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. [Import bibliotek](#0)
# 2. [Wygenerowanie danych](#1)
# 3. [Utworzenie kopii](#2)
# 4. [Zmiana typu danych i wstępna eksploracja](#3)
# 5. [LabelEncoder](#4)
# 6. [OneHotEncoder](#5)
# 7. [Pandas get_dummies](#6)
# 8. [Standaryzacja - StandardScaler](#7)
# 9. [Przygotowanie danych do modelu](#8)

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ### <a name='1'></a> Wygenerowanie danych

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %% [markdown]
# ### <a name='2'></a> Utworzenie kopi

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %% [markdown]
# ### <a name='3'></a> Zmiana typu danych i wstępna eksploracja

# %%
for col in ['size', 'color', 'gender', 'bought']:
  df[col] = df[col].astype('category')

df['weight'] = df['weight'].astype('float')

df.info()
df.describe() #wyświetla statystyki dla kolumn numerycznych
df.describe().T # dokładniejsze dane np średnia, odchylenie standardowe dla kolum numerycznych
df.describe(include=["category"]).T # włączam dane nienumeryczne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes
#        count unique     top freq
# size       5      3       L    2
# color      5      3   green    2
# gender     5      2  female    3
# bought     5      2     yes    3

# %% [markdown]
# ### <a name='4'></a> LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df["bought"])
le.transform(df["bought"])
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.fit_transform(df["bought"]) # to co wyżej w jednym kroku
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df["bought"] = le.fit_transform(df["bought"])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0     500       1
# 1    L  green    male   89.0     450       0
# 2    M   blue    male   99.0     300       1
# 3    L  green  female  129.0     380       0
# 4    M    red  female   79.0     410       1

# %%
df["bought"] = le.inverse_transform(df["bought"]) # odwrotność tego co wyżej
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue    male   99.0   300.0    yes
# 3    L  green  female  129.0   380.0     no
# 4    M    red  female   79.0   410.0    yes

# %% [markdown]
# ###  <a name='5'></a> OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
encoder.fit(df[["size"]])
# Out:
# OneHotEncoder(sparse_output=False)

# %%
encoder.transform(df[["size"]])
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %%
encoder.categories_
# Out:
# [array(['L', 'M', 'XL'], dtype=object)]

# %%
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoder.fit(df[["size"]])
encoder.transform(df[["size"]])
# Out:
# array([[0., 1.],
#        [0., 0.],
#        [1., 0.],
#        [0., 0.],
#        [1., 0.]])

# %% [markdown]
# ### <a name='6'></a> Pandas get_dummies

# %%
pd.get_dummies(data=df, dtype=int)
# Out:
#    price  weight  bought  size_L  size_M  size_XL  color_blue  color_green  \
# 0  199.0     500       1       0       0        1           0            0
# 1   89.0     450       0       1       0        0           0            1
# 2   99.0     300       1       0       1        0           1            0
# 3  129.0     380       0       1       0        0           0            1
# 4   79.0     410       1       0       1        0           0            0
#
#    color_red  gender_female  gender_male
# 0          1              1            0
# 1          0              0            1
# 2          0              0            1
# 3          0              1            0
# 4          1              1            0

# %%
pd.get_dummies(data=df, drop_first=True, dtype=int)
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0     500       1       0        1            0          1            0
# 1   89.0     450       0       0        0            1          0            1
# 2   99.0     300       1       1        0            0          0            1
# 3  129.0     380       0       0        0            1          0            0
# 4   79.0     410       1       1        0            0          1            0

# %%
pd.get_dummies(data=df, drop_first=True, dtype=int, prefix='new', prefix_sep='-')
# Out:
#    price  weight  bought  new-M  new-XL  new-green  new-red  new-male
# 0  199.0     500       1      0       1          0        1         0
# 1   89.0     450       0      0       0          1        0         1
# 2   99.0     300       1      1       0          0        0         1
# 3  129.0     380       0      0       0          1        0         0
# 4   79.0     410       1      1       0          0        1         0

# %%
pd.get_dummies(data=df, drop_first=True, dtype=int, prefix='new', prefix_sep='-', columns=['size'])
# Out:
#    color  gender  price  weight  bought  new-M  new-XL
# 0    red  female  199.0     500       1      0       1
# 1  green    male   89.0     450       0      0       0
# 2   blue    male   99.0     300       1      1       0
# 3  green  female  129.0     380       0      0       0
# 4    red  female   79.0     410       1      1       0

# %% [markdown]
# ### <a name='7'></a> Standaryzacja - StandardScaler
# std() -> pandas nieobciążony
#
# std() -> numpy obciążony

# %%
print(f"{df['price']}\n")
print(f"AVG: {df['price'].mean()}")
print(f"std: {df['price'].std():.4f}")
# Out:
# 0    199.0
# 1     89.0
# 2     99.0
# 3    129.0
# 4     79.0
# Name: price, dtype: float64
#
# AVG: 119.0
# std: 48.4768

# %%
(df['price'] - df['price'].mean()) / df['price'].std()
# Out:
# 0    1.650274
# 1   -0.618853
# 2   -0.412568
# 3    0.206284
# 4   -0.825137
# Name: price, dtype: float64

# %%
def standartdize(x):
  return (x - x.mean()) / x.std()

standartdize(df['price'])
# Out:
# 0    1.650274
# 1   -0.618853
# 2   -0.412568
# 3    0.206284
# 4   -0.825137
# Name: price, dtype: float64

# %%
from sklearn.preprocessing import scale

scale(df['price'])
# Out:
# array([ 1.84506242, -0.69189841, -0.4612656 ,  0.2306328 , -0.92253121])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df[['price']])
# Out:
# array([[ 1.84506242],
#        [-0.69189841],
#        [-0.4612656 ],
#        [ 0.2306328 ],
#        [-0.92253121]])

# %%
scaler = StandardScaler()
df[['price', 'weight']] = scaler.fit_transform(df[['price', 'weight']])
df
# Out:
#   size  color  gender     price    weight bought
# 0   XL    red  female  1.845062  1.366002    yes
# 1    L  green    male -0.691898  0.623610     no
# 2    M   blue    male -0.461266 -1.603567    yes
# 3    L  green  female  0.230633 -0.415740     no
# 4    M    red  female -0.922531  0.029696    yes

# %% [markdown]
# ### <a name='8'></a> Przygotowanie danych do modelu

# %%
df = df_raw.copy()
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
le = LabelEncoder()
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0     500       1
# 1    L  green    male   89.0     450       0
# 2    M   blue    male   99.0     300       1
# 3    L  green  female  129.0     380       0
# 4    M    red  female   79.0     410       1

# %%
scaler = StandardScaler()
df[['price', 'weight']] = scaler.fit_transform(df[['price', 'weight']])
df
# Out:
#       price    weight  bought  size_M  size_XL  color_green  color_red  \
# 0  1.845062  1.366002       1       0        1            0          1
# 1 -0.691898  0.623610       0       0        0            1          0
# 2 -0.461266 -1.603567       1       1        0            0          0
# 3  0.230633 -0.415740       0       0        0            1          0
# 4 -0.922531  0.029696       1       1        0            0          1
#
#    gender_male
# 0            0
# 1            1
# 2            1
# 3            0
# 4            0

# %%
df = pd.get_dummies(data=df, drop_first=True, dtype=int)
df
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0     500       1       0        1            0          1            0
# 1   89.0     450       0       0        0            1          0            1
# 2   99.0     300       1       1        0            0          0            1
# 3  129.0     380       0       0        0            1          0            0
# 4   79.0     410       1       1        0            0          1            0
